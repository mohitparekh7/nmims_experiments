# %%
import pandas as pd 
df = pd.read_csv('C:\\Users\\Acer\\AppData\\Local\\Programs\\Python\\Python38-32\\data_survey\\survey_results_public.csv')
print(df)
print(df.shape)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
import pandas as pd 

people = {'first' :'Anu','last':'Khare','email':'anushkakhare0202@gmail.com' }
#print(people)
people = {'first' :['Anu','A','U'],'last':['Khare','H','A'],'email':['anushkakhare0202@gmail.com','anushkakhare@gmail.com','anukhare0202@gmail.com']}

print(people)
df = pd.DataFrame(people)
print(df)

#df['email'] #only emails displayed

#type(df['email'])

#df[['last','email']] #prints last and email in tabular form

df.head(1) #prints the number of rows from top

df.tail(2) #prints the number of rows from bottom

df.columns #returns the name of columns 

df.iloc[0] #return the nth row from the data , iloc = integer loc
# Out:
# {'first': ['Anu', 'A', 'U'], 'last': ['Khare', 'H', 'A'], 'email': ['anushkakhare0202@gmail.com', 'anushkakhare@gmail.com', 'anukhare0202@gmail.com']}
#   first   last                       email
# 0   Anu  Khare  anushkakhare0202@gmail.com
# 1     A      H      anushkakhare@gmail.com
# 2     U      A      anukhare0202@gmail.com
# first                           Anu
# last                          Khare
# email    anushkakhare0202@gmail.com
# Name: 0, dtype: object
